# %%
import pandas as pd
import numpy as np
stock = pd.read_csv("Google_stock.csv")

# %%
stock=pd.read_csv("Google_stock.csv")
stock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-01-04   15.689439   15.753504   15.621622   15.684434   15.684434
# 1     2010-01-05   15.695195   15.711712   15.554054   15.615365   15.615365
# 2     2010-01-06   15.662162   15.662162   15.174174   15.221722   15.221722
# 3     2010-01-07   15.250250   15.265265   14.831081   14.867367   14.867367
# 4     2010-01-08   14.814815   15.096346   14.742492   15.065566   15.065566
# ...          ...         ...         ...         ...         ...         ...
# 3748  2024-11-22  165.850006  166.460007  163.899994  164.759995  164.759995
# 3749  2024-11-25  166.089996  168.630005  165.610001  167.649994  167.649994
# 3750  2024-11-26  167.630005  169.820007  167.580002  169.119995  169.119995
# 3751  2024-11-27  169.000000  169.479996  168.020004  169.229996  169.229996
# 3752  2024-11-29  168.500000  169.429993  167.160004  168.949997  168.949997
#
#          Volume
# 0      78169752
# 1     120067812
# 2     158988852
# 3     256315428
# 4     188783028
# ...         ...
# 3748   38604600
# 3749   33135300
# 3750   20486700
# 3751   19266500
# 3752   14257200
#
# [3753 rows x 7 columns]

# %%
stock.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2010-01-04  15.689439  15.753504  15.621622  15.684434  15.684434
# 1  2010-01-05  15.695195  15.711712  15.554054  15.615365  15.615365
# 2  2010-01-06  15.662162  15.662162  15.174174  15.221722  15.221722
# 3  2010-01-07  15.250250  15.265265  14.831081  14.867367  14.867367
# 4  2010-01-08  14.814815  15.096346  14.742492  15.065566  15.065566
#
#       Volume
# 0   78169752
# 1  120067812
# 2  158988852
# 3  256315428
# 4  188783028

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3753 entries, 0 to 3752
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3753 non-null   object
#  1   Open       3753 non-null   float64
#  2   High       3753 non-null   float64
#  3   Low        3753 non-null   float64
#  4   Close      3753 non-null   float64
#  5   Adj Close  3753 non-null   float64
#  6   Volume     3753 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 205.4+ KB

# %%
stock.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3753.000000  3753.000000  3753.000000  3753.000000  3753.000000
# mean     60.709583    61.334691    60.094759    60.727546    60.727546
# std      45.987296    46.499637    45.501034    46.004277    46.004277
# min      10.968719    11.068068    10.851602    10.912663    10.912663
# 25%      22.608858    22.780279    22.459961    22.628128    22.628128
# 50%      47.193501    47.494999    46.840000    47.162998    47.162998
# 75%      91.699997    92.570000    90.370003    91.290001    91.290001
# max     190.309998   191.750000   189.029999   191.179993   191.179993
#
#              Volume
# count  3.753000e+03
# mean   5.631459e+07
# std    4.757982e+07
# min    9.312000e+06
# 25%    2.741400e+07
# 50%    3.775600e+07
# 75%    7.345847e+07
# max    5.923990e+08

# %%
sample1=stock.iloc[0:100]
sample1
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2010-01-04  15.689439  15.753504  15.621622  15.684434  15.684434
# 1   2010-01-05  15.695195  15.711712  15.554054  15.615365  15.615365
# 2   2010-01-06  15.662162  15.662162  15.174174  15.221722  15.221722
# 3   2010-01-07  15.250250  15.265265  14.831081  14.867367  14.867367
# 4   2010-01-08  14.814815  15.096346  14.742492  15.065566  15.065566
# ..         ...        ...        ...        ...        ...        ...
# 95  2010-05-20  12.138889  12.151652  11.856857  11.887137  11.887137
# 96  2010-05-21  11.738238  12.137137  11.621622  11.813063  11.813063
# 97  2010-05-24  12.030280  12.257007  11.931932  11.940941  11.940941
# 98  2010-05-25  11.715465  11.948198  11.611862  11.938689  11.938689
# 99  2010-05-26  12.063814  12.256256  11.886887  11.898649  11.898649
#
#        Volume
# 0    78169752
# 1   120067812
# 2   158988852
# 3   256315428
# 4   188783028
# ..        ...
# 95  196335468
# 96  387244368
# 97  173650176
# 98  120575304
# 99  138884976
#
# [100 rows x 7 columns]

# %%
sample1.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    13.725453   13.851009   13.559357   13.695936   13.695936
# std      0.800196    0.784706    0.826738    0.811221    0.811221
# min     11.715465   11.948198   11.511512   11.813063   11.813063
# 25%     13.309747   13.421609   13.173298   13.288038   13.288038
# 50%     13.677302   13.757257   13.506006   13.642518   13.642518
# 75%     14.185060   14.281093   14.085273   14.184497   14.184497
# max     15.695195   15.753504   15.621622   15.684434   15.684434
#
#              Volume
# count  1.000000e+02
# mean   1.493816e+08
# std    6.630560e+07
# min    7.101691e+07
# 25%    1.059390e+08
# 50%    1.328350e+08
# 75%    1.737491e+08
# max    4.889306e+08

# %%
 stock.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
stock.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
stock.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Standardize column names
stock.rename(columns=lambda x: x.strip().replace('.', '_'), inplace=True) 
#Removing rows with any missing values
stock = stock.dropna()
 #Removing Duplicates 
stock = stock.drop_duplicates() 
# Count duplicate rows 
stock.duplicated().sum()
# Out:
# np.int64(0)

# %%
stock.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# Importing the necessary libraries
import pandas as pd

# Loading the dataset
stock = pd.read_csv("Google_stock.CSV")

# Displaying general information about the dataset
print("General Information about the Dataset:")
stock.info()

# Displaying a sample of the data
print("\nSample Data:")
print(stock.head())
# Out:
# General Information about the Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3753 entries, 0 to 3752
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3753 non-null   object
#  1   Open       3753 non-null   float64
#  2   High       3753 non-null   float64
#  3   Low        3753 non-null   float64
#  4   Close      3753 non-null   float64
#  5   Adj Close  3753 non-null   float64
#  6   Volume     3753 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 205.4+ KB
#
# Sample Data:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2010-01-04  15.689439  15.753504  15.621622  15.684434  15.684434
# 1  2010-01-05  15.695195  15.711712  15.554054  15.615365  15.615365
# 2  2010-01-06  15.662162  15.662162  15.174174  15.221722  15.221722
# 3  2010-01-07  15.250250  15.265265  14.831081  14.867367  14.867367
# 4  2010-01-08  14.814815  15.096346  14.742492  15.065566  15.065566
#
#       Volume
# 0   78169752
# 1  120067812
# 2  158988852
# 3  256315428
# 4  188783028

# %%
# Descriptive Statistics for Google Stock Price
print("\nDescriptive Statistics for Google Stock Price Metrics:")
stock_metrics = ["Open", "Close", "High", "Low", "Volume"]
print(sample1[stock_metrics].describe())
# Out:
# Descriptive Statistics for Google Stock Price Metrics:
#              Open       Close        High         Low        Volume
# count  100.000000  100.000000  100.000000  100.000000  1.000000e+02
# mean    13.725453   13.695936   13.851009   13.559357  1.493816e+08
# std      0.800196    0.811221    0.784706    0.826738  6.630560e+07
# min     11.715465   11.813063   11.948198   11.511512  7.101691e+07
# 25%     13.309747   13.288038   13.421609   13.173298  1.059390e+08
# 50%     13.677302   13.642518   13.757257   13.506006  1.328350e+08
# 75%     14.185060   14.184497   14.281093   14.085273  1.737491e+08
# max     15.695195   15.684434   15.753504   15.621622  4.889306e+08

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Histogram for price columns
sample1[["Open", "Close", "High", "Low"]].hist(bins=20, figsize=(10, 6))
plt.suptitle('Histograms for Google Stock Price')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
ax = sns.boxplot(data=sample1[["Open", "Close", "High", "Low"]])
for i, column in enumerate(["Open", "Close", "High", "Low"]):
    values = sample1[column]
    median = values.median()
    q1 = values.quantile(0.25)
    q3 = values.quantile(0.75)
    min_val = values.min()
    max_val = values.max()
    ax.text(i, median, f'Median: {median:.2f}', ha='center', color='black', fontsize=12)
    ax.text(i - 0.1, q1, f'Q1: {q1:.2f}', ha='center', color='black', fontsize=12)
    ax.text(i + 0.1, q3, f'Q3: {q3:.2f}', ha='center', color='black', fontsize=12)
    ax.text(i - 0.1, min_val, f'Min: {min_val:.2f}', ha='center', color='red', fontsize=12)
    ax.text(i + 0.1, max_val, f'Max: {max_val:.2f}', ha='center', color='red', fontsize=12)
plt.title('Box Plots for Stock Prices with Actual Values', fontsize=14)
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(sample1[["Open", "Close", "High", "Low", "Volume"]].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Google Stock Metrics')
plt.show()

# %%
# Skewness and Kurtosis
print(sample1[["Open", "Close", "High", "Low"]].skew())
print(sample1[["Open", "Close", "High", "Low"]].kurt())
# Out:
# Open    -0.024005
# Close   -0.140370
# High    -0.025077
# Low     -0.241700
# dtype: float64
# Open     0.414047
# Close    0.054276
# High     0.109285
# Low      0.280230
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Take the first 30 rows from the dataset
sample_30 = sample1.iloc[:10]

# Plotting time series for Open, Close, High, and Low prices
plt.figure(figsize=(12, 6))
plt.plot(sample_30['Date'], sample_30['Open'], label='Open', color='blue')
plt.plot(sample_30['Date'], sample_30['Close'], label='Close', color='green')
plt.plot(sample_30['Date'], sample_30['High'], label='High', color='red')
plt.plot(sample_30['Date'], sample_30['Low'], label='Low', color='orange')

plt.title('Time Series Line Plot for Stock Prices ')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import plotly.graph_objects as go
sample_20 = sample1.iloc[:20]
fig = go.Figure(data=[go.Candlestick(
    x=sample_20['Date'],
    open=sample_20['Open'],
    high=sample_20['High'],
    low=sample_20['Low'],
    close=sample_20['Close']
)])
fig.update_layout(
    title='Google Stock Price Candlestick Chart (First 20 Rows)',
    xaxis_title='Date',
    yaxis_title='Price',
    xaxis_rangeslider_visible=False
)
fig.show()

# %%
import matplotlib.pyplot as plt
sample_20 = sample1.iloc[:10]
plt.figure(figsize=(12, 6))
plt.plot(sample_20['Date'], sample_20['Volume'], color='blue')
plt.title('Google Stock Trading Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

sample_20 = sample1.iloc[:50]
sample_20['Date'] = pd.to_datetime(sample_20['Date'])
sample_20['Month'] = sample_20['Date'].dt.to_period('M')
monthly_avg_close = sample_20.groupby('Month')['Close'].mean()
plt.figure(figsize=(10, 5))
monthly_avg_close.plot(kind='bar', color='blue')
plt.title('Average Close Price Per Month ')
plt.xlabel('Month')
plt.ylabel('Average Close Price')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/rp/cxr0h_0964d4dmrzwrqncphw0000gn/T/ipykernel_6199/3422707519.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/rp/cxr0h_0964d4dmrzwrqncphw0000gn/T/ipykernel_6199/3422707519.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=sample1['Volume'], y=sample1['Close'], color='purple')
plt.title('Scatter Plot of Volume vs Close Price')
plt.xlabel('Volume')
plt.ylabel('Close Price')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sample_20 = sample1.iloc[:20]
plt.figure(figsize=(10, 5))
sns.scatterplot(x=sample_20['Volume'], y=sample_20['Close'], color='purple')
plt.title('Scatter Plot of Volume vs Close Price ')
plt.xlabel('Volume')
plt.ylabel('Close Price')
plt.tight_layout()
plt.show()

# %%
average_close = sample1['Close'].mean()
above_avg = sample1[sample1['Close'] > average_close].shape[0]
below_avg = sample1[sample1['Close'] <= average_close].shape[0]

labels = ['Above Average Close', 'Below Average Close']
sizes = [above_avg, below_avg]
colors = ['red', 'purple']

plt.figure(figsize=(5, 5))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Above and Below Average Close Prices')
plt.axis('equal')  
plt.show()

# %%
correlation = sample1[['Open', 'High', 'Low', 'Close', 'Volume']].corr()
print(correlation)
# Out:
#             Open      High       Low     Close    Volume
# Open    1.000000  0.991314  0.978336  0.978177  0.037749
# High    0.991314  1.000000  0.979648  0.989471  0.074084
# Low     0.978336  0.979648  1.000000  0.987802 -0.038305
# Close   0.978177  0.989471  0.987802  1.000000  0.003912
# Volume  0.037749  0.074084 -0.038305  0.003912  1.000000

# %%
stock_count=sample1['High'].value_counts()
print("highest stock price in google stock data")
print(stock_count)
# Out:
# highest stock price in google stock data
# High
# 15.753504    1
# 14.286537    1
# 14.005506    1
# 13.863614    1
# 14.234484    1
#             ..
# 13.598599    1
# 13.616867    1
# 13.442192    1
# 13.525776    1
# 12.256256    1
# Name: count, Length: 100, dtype: int64

# %%
print(stock.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
sample1.value_counts()
# Out:
# Date        Open       High       Low        Close      Adj Close  Volume
# 2010-01-04  15.689439  15.753504  15.621622  15.684434  15.684434  78169752     1
# 2010-04-06  14.250751  14.286537  14.149149  14.219720  14.219720  82321596     1
# 2010-04-20  13.868118  14.005506  13.790290  13.889890  13.889890  118976904    1
# 2010-04-19  13.732482  13.863614  13.638639  13.766266  13.766266  155604240    1
# 2010-04-16  14.089089  14.234484  13.754505  13.767518  13.767518  488930580    1
#                                                                                ..
# 2010-02-17  13.563564  13.598599  13.453704  13.468719  13.468719  81106812     1
# 2010-02-16  13.435185  13.616867  13.370871  13.546046  13.546046  146029824    1
# 2010-02-12  13.337588  13.442192  13.275776  13.341341  13.341341  91096812     1
# 2010-02-11  13.346346  13.525776  13.250751  13.423423  13.423423  96303600     1
# 2010-05-26  12.063814  12.256256  11.886887  11.898649  11.898649  138884976    1
# Name: count, Length: 100, dtype: int64

# %%
np.quantile(sample1[['Open','High','Low','Close','Adj Close']],[0.25],axis=0)
# Out:
# array([[13.30974746, 13.4216094 , 13.17329812, 13.28803802, 13.28803802]])

# %%
np.quantile(sample1[['Open','High','Low','Close','Adj Close']],[0.50],axis=0)
# Out:
# array([[13.67730188, 13.75725746, 13.50600624, 13.64251757, 13.64251757]])

# %%
np.quantile(sample1[['Open','High','Low','Close','Adj Close']],[0.75],axis=0)
# Out:
# array([[14.18506002, 14.28109336, 14.08527279, 14.18449736, 14.18449736]])

# %%
from scipy.stats import zscore
import pandas as pd

# Assuming sample1 is defined as in your previous context
# Select only numerical columns (e.g., exclude 'Date')
numerical_columns = ['Open', 'Close', 'High', 'Low', 'Adj Close', 'Volume']
z_scores = zscore(sample1[numerical_columns], axis=0)

# Convert the result back to a DataFrame for easier handling
z_scores_df = pd.DataFrame(z_scores, columns=numerical_columns, index=sample1.index)

# Display the result
print(z_scores_df)
# Out:
#         Open     Close      High       Low  Adj Close    Volume
# 0   2.466747  2.463589  2.436681  2.507028   2.463589 -1.079405
# 1   2.473977  2.378018  2.383155  2.424888   2.378018 -0.444328
# 2   2.432487  1.890325  2.319692  1.963080   1.890325  0.145624
# 3   1.915130  1.451308  1.811355  1.545994   1.451308  1.620867
# 4   1.368227  1.696861  1.595005  1.438298   1.696861  0.597234
# ..       ...       ...       ...       ...        ...       ...
# 95 -1.992708 -2.240955 -2.176505 -2.069673  -2.240955  0.711711
# 96 -2.495922 -2.332728 -2.195095 -2.355641  -2.332728  3.605443
# 97 -2.129120 -2.174297 -2.041569 -1.978406  -2.174297  0.367855
# 98 -2.524525 -2.177087 -2.437085 -2.367505  -2.177087 -0.436636
# 99 -2.087002 -2.226693 -2.042530 -2.033167  -2.226693 -0.159104
#
# [100 rows x 6 columns]

# %%
from scipy.stats import zscore
zscore(sample1.Close,axis=0)
# Out:
# array([ 2.46358851,  2.37801771,  1.89032533,  1.45130826,  1.69686116,
#         1.66864751,  1.33907515,  1.23397136,  1.31954217,  1.01415327,
#         1.25040284,  1.02686412,  1.10654502,  0.08434349, -0.22600663,
#        -0.1509774 , -0.16089867, -0.40303932, -0.53790692, -0.44241484,
#        -0.50132216, -0.20058375, -0.63587901, -0.49605138, -0.42846339,
#        -0.3363812 , -0.3980781 , -0.3376218 , -0.43931452, -0.18570125,
#        -0.28150407, -0.12617363, -0.20244347, -0.13919523, -0.37885704,
#        -0.49047103, -0.64673014, -0.63525989, -0.45264567, -0.1931425 ,
#        -0.06106449,  0.22634159,  0.52459881,  0.47096227,  0.3999644 ,
#         0.90408944,  1.04949742,  0.99989107,  0.49266572,  0.55529366,
#         0.56645553,  0.59249871,  0.39407332,  0.31656288,  0.05302952,
#         0.3112921 ,  0.48336475,  0.47747366,  0.47003241,  0.60211042,
#         0.61482127,  0.66690765,  0.73542785,  0.64892601,  0.50382759,
#         0.62629271,  0.58691837,  0.78875483,  1.22405009,  1.29318942,
#         1.48851331,  0.08868442,  0.08713308,  0.24029305,  0.21735018,
#        -0.0071184 , -0.07129768, -0.48520025, -0.56518952, -0.56115934,
#        -0.47403956, -0.66936345, -0.51744408, -1.268671  , -1.16356721,
#        -1.50740177, -1.67885294, -0.79493007, -1.18558021, -1.29905511,
#        -1.12884218, -1.23270654, -1.21906465, -1.51670274, -1.6388583 ,
#        -2.24095543, -2.33272806, -2.17429731, -2.17708689, -2.22669324])

# %%
x=pd.Series(sample1['Open'])
y=pd.Series(sample1['Close'])
print("c",x.corr(y))
# Out:
# c 0.9781770992637875

# %%
import matplotlib.pyplot as plt
x = ["2010-01-04", "2010-01-05", "2010-01-06", "2010-01-07", "2010-01-08"] 
y = [15.753504, 15.711712, 15.662162, 15.265265, 15.096346] 
plt.bar(x, y)

plt.xlabel("Date", fontsize=15)
plt.ylabel("High Price", fontsize=15)
plt.title("Google Stock High Prices", fontsize=15)

plt.show()

# %%
labels = ["2010-01-04", "2010-01-05", "2010-01-06", "2010-01-07", "2010-01-08"] 
sizes = [15.753504, 15.711712, 15.662162, 15.265265, 15.096346]  
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Google Stock High Prices Distribution")

plt.show()

# %%
plt.hist(sample1['Open'], bins=30, color='blue', edgecolor='black')

plt.title('Histogram of Google Open Stock Prices', fontsize=15)
plt.xlabel('Stock Price', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()
